# %% [markdown]
# # Problem Set 3

# %% [markdown]
# # Question : 1

# %% [markdown]
# Step : 1 Inserted The libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step : 2 Imported the dataset from the address

# %%
DatasetLink = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'

# %% [markdown]
#  Step 3 : Assign it to a variablr called users

# %%
users = pd.read_csv(DatasetLink , delimiter='|')

# %% [markdown]
# Step 4: Discover what is the mean age per occupation

# %%
meanOfAge_per_occupation = users.groupby('occupation')['age'].mean()
meanOfAge_per_occupation
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# Step 5: Discover the Male ratio per occupation and sort it from the most to the least

# %%
male_ratio_by_occupation = users.groupby('occupation').apply(lambda x: (x['gender'] == 'M').mean()).sort_values(ascending=False)
male_ratio_by_occupation
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# dtype: float64

# %% [markdown]
# Step : 6 For each occupation,calculate the minimum and maximum ages

# %%
min_max_age_per_occupation = users.groupby('occupation')['age'].describe()[['min', 'max']]

min_max_age_per_occupation
# Out:
#                 min   max
# occupation
# administrator  21.0  70.0
# artist         19.0  48.0
# doctor         28.0  64.0
# educator       23.0  63.0
# engineer       22.0  70.0
# entertainment  15.0  50.0
# executive      22.0  69.0
# healthcare     22.0  62.0
# homemaker      20.0  50.0
# lawyer         21.0  53.0
# librarian      23.0  69.0
# marketing      24.0  55.0
# none           11.0  55.0
# other          13.0  64.0
# programmer     20.0  63.0
# retired        51.0  73.0
# salesman       18.0  66.0
# scientist      23.0  55.0
# student         7.0  42.0
# technician     21.0  55.0
# writer         18.0  60.0

# %% [markdown]
# Step : 7 Foe each combination of occupation and sex,calculatr the mean age

# %%
mean_age_by_gender_and_occupation = users.groupby(['occupation', 'gender'])['age'].mean()
mean_age_by_gender_and_occupation
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# Step : 8 For each occupation presetn the percentage of women and men

# %%
# Group the data by occupation and gender, and count the number of users in each group
gender_counts = users.groupby(['occupation', 'gender']).size()

# Group the data by occupation and calculate the total number of users in each occupation
occupation_totals = users.groupby('occupation').size()

# Calculate the percentage of women and men for each occupation
women_per = gender_counts.loc[:, 'F'] / occupation_totals * 100
men_per = gender_counts.loc[:, 'M'] / occupation_totals * 100

# Create a new DataFrame with the results
gender_percentages = pd.DataFrame({'Percentage Women': women_per, 'Percentage Men': men_per})

# Display the result
gender_percentages
# Out:
#                Percentage Women  Percentage Men
# occupation
# administrator         45.569620       54.430380
# artist                46.428571       53.571429
# doctor                      NaN      100.000000
# educator              27.368421       72.631579
# engineer               2.985075       97.014925
# entertainment         11.111111       88.888889
# executive              9.375000       90.625000
# healthcare            68.750000       31.250000
# homemaker             85.714286       14.285714
# lawyer                16.666667       83.333333
# librarian             56.862745       43.137255
# marketing             38.461538       61.538462
# none                  44.444444       55.555556
# other                 34.285714       65.714286
# programmer             9.090909       90.909091
# retired                7.142857       92.857143
# salesman              25.000000       75.000000
# scientist              9.677419       90.322581
# ...

# %% [markdown]
# # Question : 2

# %% [markdown]
# Step : 1 Inserted the libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Step: 2 imported the dataset by given address

# %%
Url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv'

# %% [markdown]
# Step: 3 Assign to it variable called euro12

# %%
euro12 = pd.read_csv(Url , delimiter = ',')

# %% [markdown]
# Step: 4 Select only the Goal column

# %%
euro12["Goals"]
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# Step : 5 How many teams participanted in the euro2012?

# %%
euro12['Team'].nunique()
# Out:
# 16

# %% [markdown]
# Stewp :  6 What is the number of column in the dataset?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# Step : 7 View the column Tean, yellow cards and red cards and assign them to a dataframe called discipline

# %%
discipline = euro12[['Team','Yellow Cards','Red Cards']]

# %% [markdown]
# Step : 8 Sort the teams by red cards then to yellow cards

# %%
discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending=[False, False])
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# Step : 9 Calculate the mean yellow cards given teh teams

# %%
discipline['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# Step : 10 & 11 Filter teams that scored more than 6 goals and select the teams that start with G

# %%
euro12[euro12['Goals'] > 6]['Team']
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# Step 12 Slect the first 7 column

# %%
euro12.iloc[:,:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step : 13 Select all column except the last 3

# %%
euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step : 14 Present only the shooting accuracy from England,Italy and Russia

# %%
euro12.loc[euro12['Team'].isin(['England', 'Italy', 'Russia']), ['Team', 'Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question : 3

# %% [markdown]
# Step : 1 Imported the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step : 2 Create 3 diffrent series, each of length 100 as follows:
#
# 1.The first a random number from 1 to 4
# 2.The second a random number from 1 to 3
# 3.The third a random number from 10,000 to 30,000

# %%
Sr1 = pd.Series(np.random.randint(1, 5, size=100))

Sr2 = pd.Series(np.random.randint(1, 4, size=100))

Sr3 = pd.Series(np.random.randint(10000, 30001, size=100))

# %% [markdown]
# Step 3 : Create a DataFrame by joinning the Series by column

# %%
df = pd.concat([Sr1 , Sr2 , Sr3],axis = 1)
df
# Out:
#     0  1      2
# 0   3  2  21175
# 1   1  3  21392
# 2   3  2  19987
# 3   4  2  14916
# 4   3  1  25752
# .. .. ..    ...
# 95  4  1  15254
# 96  3  1  26521
# 97  3  3  10570
# 98  4  1  13142
# 99  4  1  15154
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 4 : Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df.columns = ['bedrs', 'bathrs', 'price_sqr_meter']

# %% [markdown]
# Step 5 : Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn = pd.concat([Sr1, Sr2, Sr3], axis=0, ignore_index=True)
bigcolumn = pd.DataFrame(bigcolumn, columns=['bigcolumn'])

# %% [markdown]
# Step 6 : Ops it seems it is going only until index 99. Is it true?
#
# Answer : True

# %% [markdown]
# Step 7 : Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn = bigcolumn.reset_index(drop=True)
bigcolumn
# Out:
#      bigcolumn
# 0            3
# 1            1
# 2            3
# 3            4
# 4            3
# ..         ...
# 295      15254
# 296      26521
# 297      10570
# 298      13142
# 299      15154
#
# [300 rows x 1 columns]

# %% [markdown]
# # Question : 4

# %% [markdown]
# Step 1 : Imported the Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step 2 : Import the dataset from the attached file wind.txt

# %%
url = "C:/Users/Owner/OneDrive - Georgian College/Desktop/Wind.txt"

# %% [markdown]
# Step 3 : Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_csv(url,sep = '\s+',parse_dates=[[0,1,2]])

data = data.rename(columns={'Yr_Mo_Dy': 'DATE'})


data['DATE'] = pd.to_datetime(data['DATE'], format='%Y_%m_%d')
data = data.set_index('DATE')

data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# DATE
# 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# DATE
# 2061-01-01  12.58  18.50  15.04
# 2061-01-02   9.67  17.54  13.83
# 2061-01-03   7.67  12.75  12.71
# 2061-01-04   5.88   5.46  10.88
# 2061-01-05  10.34  12.92  11.83

# %% [markdown]
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
# Define a function to adjust year
def fix_year(x):
    year = x.year - 100 if x.year > 1989 else x.year
    return pd.to_datetime(year * 10000 + x.month * 100 + x.day, format='%Y%m%d')

# Apply the function to fix the year in the date column
data.index = data.index.map(fix_year)

data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# DATE
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# DATE
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %% [markdown]
# Step 5 : Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.index
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='DATE', length=6574, freq=None)

# %% [markdown]
# Step 6 : Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below

# %%
data.isna().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# Step 7 : Compute how many non-missing values there are in total

# %%
data.notna().sum().sum()
# Out:
# 78857

# %% [markdown]
# Step 8 : Calculate the mean windspeeds of the windspeeds over all the locations and all the times.

# %%
data.mean().mean()
# Out:
# 10.227982360836938

# %% [markdown]
# Step 9 : Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days

# %%
loc_stats = pd.DataFrame({
    'min': data.min(),
    'max': data.max(),
    'mean': data.mean(),
    'std': data.std()
})

loc_stats
# Out:
#       min    max       mean       std
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794

# %% [markdown]
# Step 10 : Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day. A different set of numbers for each day.

# %%
day_stats = pd.DataFrame({
    'min': data.min(axis=1),
    'max': data.max(axis=1),
    'mean': data.mean(axis=1),
    'std': data.std(axis=1)
})

day_stats.head()
# Out:
#              min    max       mean       std
# DATE
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %% [markdown]
# Step 11. Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.

# %%
jan_data = data[data.index.month == 1]

jan_data.mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# Step 12 : Downsample the record to a yearly frequency for each location.

# %%
yearly_data = data.resample('AS').mean()
yearly_data
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# DATE
# 1961-01-01  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-01-01  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-01-01  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-01-01  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-01-01  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-01-01  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-01-01  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-01-01  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-01-01  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-01-01  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-01-01  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# Step 13 : Downsample the record to a monthly frequency for each location

# %%
monthly_data = data.resample('M').mean()
monthly_data
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# DATE
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# Step 14 : Downsample the record to a weekly frequency for each location.

# %%
weekly_data = data.resample('W').mean()
weekly_data
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# DATE
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %% [markdown]
# Step 15 : Min, max, mean, and standard deviation for each week for the first 52 weeks

# %%
weekly_stats = data.resample('W').agg(['min', 'max', 'mean', 'std'])
weekly_stats = weekly_stats.loc['1961-01-02':'1961-12-31']  # select the first 52 weeks
weekly_stats
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# DATE
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
# 1961-03-19   4.92  16.88  11.911429  3.860036   9.46  15.54  13.501429
# ...

# %% [markdown]
# # Question : 5

# %% [markdown]
# Step 1 : import the libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Step 2 : import the dataset

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %% [markdown]
# Step 3 : assigned to variable chipo

# %%
chipo = pd.read_csv(url ,sep = '\t' )
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# Step 4 : see the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# Step 5 : What is the number of observations in the dataset?

# %%
len(chipo)
# Out:
# 4622

# %% [markdown]
# Step 6 : What is the number of column in the dataset?

# %%
len(chipo.columns)
# Out:
# 5

# %% [markdown]
# Step 7 : print all the name of the columns

# %%
for i in chipo.columns:
    print(i)
# Out:
# order_id
# quantity
# item_name
# choice_description
# item_price

# %% [markdown]
# Step 8 : how is the dataset indexed

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# Step 9 : Which was the most-ordered item?

# %%
import warnings

# Filter out the specific FutureWarning related to numeric_only parameter
warnings.filterwarnings("ignore", category=FutureWarning, message="The default value of numeric_only in DataFrameGroupBy.sum is deprecated.")


item_count = chipo.groupby('item_name').sum()
item_count = item_count.sort_values(['quantity'], ascending=False)
item_count.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# Step 10 : For the most-ordered item, how many items were ordered?

# %%
item_count.head(1).quantity
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %% [markdown]
# Step 11 : What was the most ordered item in the choice_description column?

# %%
import warnings

# Filter out the specific FutureWarning related to numeric_only parameter
warnings.filterwarnings("ignore", category=FutureWarning, message="The default value of numeric_only in DataFrameGroupBy.sum is deprecated.")

choice_count = chipo.groupby('choice_description').sum()
choice_count = choice_count.sort_values(['quantity'], ascending=False)
choice_count.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# Step 12 : How many items were orderd in total?

# %%
total_items = chipo['quantity'].sum()
total_items
# Out:
# 4972

# %% [markdown]
# Step 13 : • Turn the item price into a float • Check the item price type • Create a lambda function and change the type of item price • Check the item price type

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:-1]))
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Step 14 : How much was the revenue for the period in the dataset?

# %%
revenue = (chipo['quantity'] * chipo['item_price']).sum()
revenue
# Out:
# 39237.02

# %% [markdown]
# Step 15 : How many orders were made in the period?

# %%
total_orders = chipo['order_id'].nunique()
total_orders
# Out:
# 1834

# %% [markdown]
# Step 16 : What is the average revenue amount per order?

# %%
avg_rev_per_order = revenue/total_orders
avg_rev_per_order
# Out:
# 21.39423118865867

# %% [markdown]
# Step 17 : How many different items are sold?

# %%
diff_item = chipo['item_name'].nunique()
diff_item
# Out:
# 50

# %% [markdown]
# # Question : 6

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the data 
url = "C:/Users/Owner/Downloads/us-marriages-divorces-1867-2014.csv"
US_MRG_DIV = pd.read_csv(url)

# Set the year column as per index
US_MRG_DIV.set_index('Year', inplace=True)

# Create a line plot showing the number of marriages and divorces per capita
plt.plot(US_MRG_DIV['Marriages_per_1000'], label='Marriages')
plt.plot(US_MRG_DIV['Divorces_per_1000'], label='Divorces')

# Add labels and legend
plt.title('Marriages and Divorces per Capita in the U.S. (1867-2014)')
plt.xlabel('Year')
plt.ylabel('Number per 1000')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Question : 7

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "C:/Users/Owner/Downloads/us-marriages-divorces-1867-2014.csv"
data = pd.read_csv(url)


years = [1900, 1950, 2000]
df = data[data.Year.isin(years)]


fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(df.Year, df.Marriages_per_1000, width=3, align='edge', label='Marriages per capita')
ax.bar(df.Year, df.Divorces_per_1000, width=-3, align='edge', label='Divorces per capita')


ax.set_xlabel('Year')
ax.set_ylabel('Per capita')
ax.set_title('Marriages and Divorces per capita in the U.S. between 1900, 1950, and 2000')
ax.legend()
plt.show()

# %% [markdown]
# # Question : 8

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('C:/Users/Owner/Downloads/actor_kill_counts.csv') # Read the data


data = data.sort_values('Count', ascending=False) # Sort the data by kill count


plt.barh(data['Actor'], data['Count'], color='green') # Create the horizontal bar chart


plt.xlabel('Kill Count')                     # Add labels to the chart
plt.ylabel('Actor')
plt.title('Deadliest Actors in Hollywood')


plt.show()   # Display the chart

# %% [markdown]
# # Question : 9

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "C:/Users/Owner/Downloads/roman-emperor-reigns.csv"
data = pd.read_csv(url)


assassinated = data[data['Cause_of_Death'] == 'Assassinated']
fraction_assassinated = len(assassinated) / len(data)


natural_causes = data[data['Cause_of_Death'] == 'Natural Causes']
fraction_natural_causes = len(natural_causes) / len(data)


labels = ['Assassinated', 'Natural Causes']
sizes = [fraction_assassinated, fraction_natural_causes]
colors = ['blue', 'green']
explode = (0.1, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Fraction of Roman Emperors Assassinated')
plt.show()

# %% [markdown]
# # Question :  10

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Owner/Downloads/arcade-revenue-vs-cs-doctorates (1).csv")


data = data[(data['Year'] >= 2000) & (data['Year'] <= 2009)]


plt.scatter(data['Computer Science Doctorates Awarded (US)'], data['Total Arcade Revenue (billions)'], c=data['Year'], cmap='viridis')


plt.xlabel('Computer Science Doctorates Awarded (US)')
plt.ylabel('Total Arcade Revenue (billions)')


plt.colorbar(label='Year')


plt.show()  #Plot the graph
